# %% [markdown]
# <a href="https://colab.research.google.com/github/theiresearch/ArcticSeaIce/blob/main/.ipynb_checkpoints/0-Correlation_Matrix_Final-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Arctic Project in Correlation Matrix

# %% [markdown]
# ## Import libraries

# %%
library(corrplot)

# %% [markdown]
# ## Load data

# %%
arctic <-read.csv("arctic_data.csv",stringsAsFactors = F)

# %% [markdown]
# ## Correlation matrix

# %%
feature_correlations <- cor(arctic[,5:16])
corrplot(feature_correlations,method="circle",type="upper")
corrplot(feature_correlations,method="number",number.cex = 0.5,type="upper")
# Out:
# Plot with title “”
# Plot with title “”
