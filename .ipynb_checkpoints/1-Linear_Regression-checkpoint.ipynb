# %% [markdown]
# # Arctic Project in Linear Regression

# %% [markdown]
# ## Import libraries

# %%
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %% [markdown]
# ## Load data

# %%
arctic <-read.csv("arctic_data.csv",stringsAsFactors = F)

# %% [markdown]
# ## Correlation matrix

# %%
feature_correlations <- cor(arctic[,5:13])
corrplot(feature_correlations,method="circle")
# Out:
# Plot with title “”

# %% [markdown]
# ## Linear Regression

# %%
lm1<-lm(extent~rainfall+daylight+population+CO2+ozone+ocean_temp+land_temp,data=arctic)
lm1 # extent as y

lm2<-lm(area~rainfall+daylight+population+CO2+ozone+ocean_temp+land_temp,data=arctic)
lm2 # area as y
# Out:
# Call:
# lm(formula = extent ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Coefficients:
# (Intercept)     rainfall     daylight   population          CO2        ozone
#     0.50882     -0.12071     -0.09344     -0.71152      0.69196      0.72281
#  ocean_temp    land_temp
#    -0.23240      0.15227
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Coefficients:
# (Intercept)     rainfall     daylight   population          CO2        ozone
#     0.46775     -0.23012     -0.09963     -0.37215      0.43727      0.73648
#  ocean_temp    land_temp
#    -0.24536      0.14961

# %% [markdown]
# ## show results

# %%
summary(lm1)
summary(lm2)
# Out:
# Call:
# lm(formula = extent ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.30225 -0.07601  0.00724  0.07478  0.33515
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.50882    0.02779  18.311  < 2e-16 ***
# rainfall    -0.12071    0.02862  -4.217 2.95e-05 ***
# daylight    -0.09344    0.02092  -4.466 9.92e-06 ***
# population  -0.71152    0.16152  -4.405 1.30e-05 ***
# CO2          0.69196    0.17998   3.845 0.000137 ***
# ozone        0.72281    0.03457  20.911  < 2e-16 ***
# ocean_temp  -0.23240    0.04909  -4.734 2.90e-06 ***
# land_temp    0.15227    0.05566   2.736 0.006452 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1082 on 482 degrees of freedom
# Multiple R-squared:  0.8297,	Adjusted R-squared:  0.8272
# F-statistic: 335.4 on 7 and 482 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.30300 -0.07646  0.00506  0.07854  0.32239
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.46775    0.02996  15.610  < 2e-16 ***
# rainfall    -0.23012    0.03086  -7.456 4.18e-13 ***
# daylight    -0.09963    0.02256  -4.416 1.24e-05 ***
# population  -0.37215    0.17417  -2.137   0.0331 *
# CO2          0.43727    0.19408   2.253   0.0247 *
# ozone        0.73648    0.03728  19.758  < 2e-16 ***
# ocean_temp  -0.24536    0.05294  -4.635 4.60e-06 ***
# land_temp    0.14961    0.06002   2.493   0.0130 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1167 on 482 degrees of freedom
# Multiple R-squared:  0.8323,	Adjusted R-squared:  0.8299
# F-statistic: 341.7 on 7 and 482 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## AIC optimization

# %%
step(lm1)
step(lm2)
# Out:
# Start:  AIC=-2171.48
# extent ~ rainfall + daylight + population + CO2 + ozone + ocean_temp +
#     land_temp
#
#              Df Sum of Sq     RSS     AIC
# <none>                     5.6415 -2171.5
# - land_temp   1    0.0876  5.7291 -2165.9
# - CO2         1    0.1730  5.8145 -2158.7
# - rainfall    1    0.2082  5.8497 -2155.7
# - population  1    0.2271  5.8687 -2154.1
# - daylight    1    0.2335  5.8750 -2153.6
# - ocean_temp  1    0.2623  5.9038 -2151.2
# - ozone       1    5.1177 10.7593 -1857.1
# Call:
# lm(formula = extent ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Coefficients:
# (Intercept)     rainfall     daylight   population          CO2        ozone
#     0.50882     -0.12071     -0.09344     -0.71152      0.69196      0.72281
#  ocean_temp    land_temp
#    -0.23240      0.15227
# Start:  AIC=-2097.56
# area ~ rainfall + daylight + population + CO2 + ozone + ocean_temp +
#     land_temp
#
#              Df Sum of Sq     RSS     AIC
# <none>                     6.5601 -2097.6
# - population  1    0.0621  6.6223 -2094.9
# - CO2         1    0.0691  6.6292 -2094.4
# - land_temp   1    0.0846  6.6447 -2093.3
# - daylight    1    0.2655  6.8256 -2080.1
# - ocean_temp  1    0.2924  6.8525 -2078.2
# - rainfall    1    0.7566  7.3167 -2046.1
# - ozone       1    5.3131 11.8733 -1808.9
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + ocean_temp + land_temp, data = arctic)
#
# Coefficients:
# (Intercept)     rainfall     daylight   population          CO2        ozone
#     0.46775     -0.23012     -0.09963     -0.37215      0.43727      0.73648
#  ocean_temp    land_temp
#    -0.24536      0.14961
