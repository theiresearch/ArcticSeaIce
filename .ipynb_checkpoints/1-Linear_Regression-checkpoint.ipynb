# %% [markdown]
# # Arctic Project in Linear Regression

# %% [markdown]
# ## Import libraries

# %%
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %% [markdown]
# ## Load data

# %%
arctic <-read.csv("arctic_data.csv",stringsAsFactors = F)

# %% [markdown]
# ## Correlation matrix

# %%
feature_correlations <- cor(arctic[,5:16])
corrplot(feature_correlations,method="circle")
# Out:
# Plot with title “”

# %% [markdown]
# ## Linear Regression

# %%
lm2<-lm(area~rainfall+daylight+population+CO2+ozone
        +Ocean_Temp_NH+Land_Temp_NH+Max_Temp_NS+Ave_Temp_NS+Min_Temp_NS+GDP_WORLD,
        data=arctic)
lm2 # area as y
# Out:
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + Ocean_Temp_NH + Land_Temp_NH + Max_Temp_NS + Ave_Temp_NS +
#     Min_Temp_NS + GDP_WORLD, data = arctic)
#
# Coefficients:
#   (Intercept)       rainfall       daylight     population            CO2
#       0.68053       -0.10402        0.10512       -0.68655        1.66756
#         ozone  Ocean_Temp_NH   Land_Temp_NH    Max_Temp_NS    Ave_Temp_NS
#       0.36692       -0.23936        0.08615       -3.54599        8.72640
#   Min_Temp_NS      GDP_WORLD
#      -5.74521       -0.70459

# %% [markdown]
# ## show results

# %%
summary(lm2)
# Out:
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + Ocean_Temp_NH + Land_Temp_NH + Max_Temp_NS + Ave_Temp_NS +
#     Min_Temp_NS + GDP_WORLD, data = arctic)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.304846 -0.057427  0.004213  0.059666  0.215555
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)    0.68053    0.02825  24.092  < 2e-16 ***
# rainfall      -0.10402    0.02883  -3.608 0.000341 ***
# daylight       0.10512    0.03747   2.805 0.005235 **
# population    -0.68655    0.14252  -4.817 1.96e-06 ***
# CO2            1.66756    0.20907   7.976 1.13e-14 ***
# ozone          0.36692    0.03548  10.340  < 2e-16 ***
# Ocean_Temp_NH -0.23936    0.04759  -5.030 6.95e-07 ***
# Land_Temp_NH   0.08615    0.04214   2.044 0.041474 *
# Max_Temp_NS   -3.54599    5.12200  -0.692 0.489081
# Ave_Temp_NS    8.72640    9.90188   0.881 0.378605
# Min_Temp_NS   -5.74521    4.85297  -1.184 0.237058
# GDP_WORLD     -0.70459    0.07664  -9.194  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.0903 on 478 degrees of freedom
# Multiple R-squared:  0.9004,	Adjusted R-squared:  0.8981
# F-statistic: 392.7 on 11 and 478 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## AIC optimization

# %%
step(lm2)
# Out:
# Start:  AIC=-2344.71
# area ~ rainfall + daylight + population + CO2 + ozone + Ocean_Temp_NH +
#     Land_Temp_NH + Max_Temp_NS + Ave_Temp_NS + Min_Temp_NS +
#     GDP_WORLD
#
#                 Df Sum of Sq    RSS     AIC
# - Max_Temp_NS    1   0.00391 3.9013 -2346.2
# - Ave_Temp_NS    1   0.00633 3.9037 -2345.9
# - Min_Temp_NS    1   0.01143 3.9088 -2345.3
# <none>                       3.8974 -2344.7
# - Land_Temp_NH   1   0.03407 3.9314 -2342.4
# - daylight       1   0.06416 3.9615 -2338.7
# - rainfall       1   0.10612 4.0035 -2333.6
# - population     1   0.18921 4.0866 -2323.5
# - Ocean_Temp_NH  1   0.20628 4.1036 -2321.4
# - CO2            1   0.51870 4.4161 -2285.5
# - GDP_WORLD      1   0.68919 4.5866 -2266.9
# - ozone          1   0.87176 4.7691 -2247.8
#
# Step:  AIC=-2346.22
# area ~ rainfall + daylight + population + CO2 + ozone + Ocean_Temp_NH +
#     Land_Temp_NH + Ave_Temp_NS + Min_Temp_NS + GDP_WORLD
#
#                 Df Sum of Sq    RSS     AIC
# <none>                       3.9013 -2346.2
# - Land_Temp_NH   1   0.03387 3.9351 -2344.0
# - daylight       1   0.06543 3.9667 -2340.1
# - rainfall       1   0.10461 4.0059 -2335.2
# - Ave_Temp_NS    1   0.17105 4.0723 -2327.2
# - population     1   0.18654 4.0878 -2325.3
# - Ocean_Temp_NH  1   0.20343 4.1047 -2323.3
# - Min_Temp_NS    1   0.32402 4.2253 -2309.1
# - CO2            1   0.51530 4.4166 -2287.4
# - GDP_WORLD      1   0.68878 4.5901 -2268.6
# - ozone          1   0.87013 4.7714 -2249.6
# Call:
# lm(formula = area ~ rainfall + daylight + population + CO2 +
#     ozone + Ocean_Temp_NH + Land_Temp_NH + Ave_Temp_NS + Min_Temp_NS +
#     GDP_WORLD, data = arctic)
#
# Coefficients:
#   (Intercept)       rainfall       daylight     population            CO2
#       0.68005       -0.10319        0.10608       -0.68036        1.65952
#         ozone  Ocean_Temp_NH   Land_Temp_NH    Ave_Temp_NS    Min_Temp_NS
#       0.36653       -0.23718        0.08588        1.87714       -2.39579
#     GDP_WORLD
#      -0.70438
