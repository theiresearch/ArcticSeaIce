# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error # 均方误差

 
df = pd.read_csv('arctic_data.csv')
df
# Out:
#      observation  year  month        date  Extent  AvgTemp  ArcticIceVolume
# 0              1  1980      1  01/01/1980   0.902   0.2016         0.799170
# 1              2  1980      2  01/02/1980   0.990   0.2887         0.892699
# 2              3  1980      3  01/03/1980   0.996   0.2978         0.962674
# 3              4  1980      4  01/04/1980   0.947   0.3975         1.000000
# 4              5  1980      5  01/05/1980   0.816   0.6552         0.984952
# ..           ...   ...    ...         ...     ...      ...              ...
# 485          486  2020      6  01/06/2020   0.560   0.8912         0.456819
# 486          487  2020      7  01/07/2020   0.296   0.9118         0.200234
# 487          488  2020      8  01/08/2020   0.121   0.9003         0.058390
# 488          489  2020      9  01/09/2020   0.028   0.7595         0.013312
# 489          490  2020     10  01/10/2020   0.137   0.5991         0.034905
#
# [490 rows x 7 columns]

# %%
#plot correlation matrix

cor = df.drop( df.iloc[:, [0,1,2,3]], axis=1 )
corrmat = cor.corr()
 
f, ax = plt.subplots(figsize=(8,6))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()

# %%
df['V_shift'] = df['ArcticIceVolume'].shift()
df['Volume_vary'] = df['ArcticIceVolume'] - df['V_shift']
del df['V_shift']
df = df.dropna()
df
# Out:
#      observation  year  month        date  Extent  AvgTemp  ArcticIceVolume  \
# 1              2  1980      2  01/02/1980   0.990   0.2887         0.892699
# 2              3  1980      3  01/03/1980   0.996   0.2978         0.962674
# 3              4  1980      4  01/04/1980   0.947   0.3975         1.000000
# 4              5  1980      5  01/05/1980   0.816   0.6552         0.984952
# 5              6  1980      6  01/06/1980   0.689   0.8820         0.894187
# ..           ...   ...    ...         ...     ...      ...              ...
# 485          486  2020      6  01/06/2020   0.560   0.8912         0.456819
# 486          487  2020      7  01/07/2020   0.296   0.9118         0.200234
# 487          488  2020      8  01/08/2020   0.121   0.9003         0.058390
# 488          489  2020      9  01/09/2020   0.028   0.7595         0.013312
# 489          490  2020     10  01/10/2020   0.137   0.5991         0.034905
#
#      Volume_vary
# 1       0.093529
# 2       0.069975
# 3       0.037326
# 4      -0.015048
# 5      -0.090764
# ..           ...
# 485    -0.164890
# 486    -0.256586
# 487    -0.141844
# 488    -0.045077
# 489     0.021593
#
# [489 rows x 8 columns]

# %%
# calculate loss coefficient L

# linear regression
X = df[['AvgTemp']]
y = df[['Volume_vary']]
regressor = LinearRegression()
regressor.fit(X, y)

col=df.iloc[:,5]
arr=col.values

# plot setting
plt.figure(figsize = (15,10))

plt.scatter(X, y, color = 'red')
plt.plot(arr, regressor.predict(X), color = 'blue')
plt.title('AvgTemp vs Volume_vary')
plt.xlabel('AvgTemp')
plt.ylabel('Volume_vary')
plt.show()

# %%
print('R^2 value:',round(regressor.score(X,y),3))
# Out:
# R^2 value: 0.881

# %%
print('MSE:',round(mean_squared_error(regressor.predict(X),y),5))
# Out:
# MSE: 0.00153
